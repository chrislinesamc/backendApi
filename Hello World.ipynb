# %% [markdown]
# ## Import Functions

# %%
import numpy as np
import requests
import json

# %% [markdown]
# ## Load the brain

# %%
brainDetailsJson = {
    "bioSample": 37
}

# %% [markdown]
# ## Get List of all species

# %%
apiKey = 118152289966904065849

# %%
brainsListResp = requests.get(f'https://apollo2.humanbrain.in/CC/getDetailsOfSeriesStatsAllRestricted/{apiKey}')
brainsList = json.loads(brainsListResp.text)
for i in range(len(brainsList['data'])):
    print(brainsList['data'][i]['data']['species_name'])
# Out:
# chicken (Gallus gallus domesticus)
# Goat
# Human
# Human fetus
# Mouse

# %%
for i in range(len(brainsList['data'][3]['children'][0]['children'])):
    print(brainsList['data'][3]['children'][0]['children'][i]['data']['brain_name'], brainsList['data'][3]['children'][0]['children'][i]['data']['seriesset_id'])
# Out:
# FTB 1 13
# FB_3 15
# Fetal brain 5 25
# Fetal test brain 6 41
# Fetal brain 6 42
# Fetal brain 14 44
# Fetal brain 20 46
# fetal test brain 7 47
# Fetal brain 24 48
# fetal test brain 8 49
# Fetal brain 31 50
# Fetal brain 10 51
# Fetal brain 21 52
# Fetal brain 23 56
# Fetal Brain 18 59
# Fetal brain 7 60
# Fetal brain 28 61
# Fetal brain 40 62
# fetal  brain 41 63
# fetal  brain 36 64
# Fetal brain 34 65
# Fetal brain 16 66
# Fetal brain 13 67
# Fetal brain 29 69
# fetal brain 12 70
# Fetal brain 11 71
# Fetal brain 19 76
# Fetal test brain 3 78
# Fetal brain 22 80
# fetal brain 63 82
# Fetal brain 30 83
# fetal brain 58 84

# %% [markdown]
# ## get single brain details using seriesset id

# %%
seriessetDetailsResp = requests.get('https://apollo2.humanbrain.in/GW/getBrainThumbNailDetails/IIT/V1/SS-15:-1:-1')
seriessetDetail = json.loads(seriessetDetailsResp.text)

# %%
print(seriessetDetail)
# Out:
# [{'seriesType': 'NISSL', 'thumbnails': [{'key': 'SS-15:10:7', 'brainid': 10, 'sectionNo': 7, 'sectionNotes': None, 'thumbnailUrl': 'https://apollo2.humanbrain.in/iipsrv//data/storageIIT/humanbrain/analytics/37/NISL/B_37_FB3-SL_3-ST_NISL-SE_7_thumbnail.jpg'}, {'key': 'SS-15:10:10', 'brainid': 10, 'sectionNo': 10, 'sectionNotes': None, 'thumbnailUrl': 'https://apollo2.humanbrain.in/iipsrv//data/storageIIT/humanbrain/analytics/37/NISL/B_37_FB3-SL_4-ST_NISL-SE_10_thumbnail.jpg'}, {'key': 'SS-15:10:13', 'brainid': 10, 'sectionNo': 13, 'sectionNotes': None, 'thumbnailUrl': 'https://apollo2.humanbrain.in/iipsrv//data/storageIIT/humanbrain/analytics/37/NISL/B_37_FB3-SL_5-ST_NISL-SE_13_thumbnail.jpg'}, {'key': 'SS-15:10:16', 'brainid': 10, 'sectionNo': 16, 'sectionNotes': None, 'thumbnailUrl': 'https://apollo2.humanbrain.in/iipsrv//data/storageIIT/humanbrain/analytics/37/NISL/B_37_FB3-SL_6-ST_NISL-SE_16_thumbnail.jpg'}, {'key': 'SS-15:10:19', 'brainid': 10, 'sectionNo': 19, 'sectionNotes': ''
# ...

# %% [markdown]
# ## list of series type

# %%
for i in range(len(seriessetDetail)):
    print(seriessetDetail[i]['seriesType'])
# Out:
# NISSL
# Haematoxylin and Eosin
# Block face image
# Immuno Histo Chemistry
# MRI
# Superannotate_FB3
# Fetal_Atlas_V1.33
# Superannotate_FB3_First_Hemisphere
# Fetal_Atlas_V1.40

# %% [markdown]
# ## list of section no

# %%
for i in range(len(seriessetDetail[4]['thumbnails'])):
    print(seriessetDetail[4]['thumbnails'][i]['brainid'])
# Out:
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85

# %%
sectionDetaisRest = requests.get('https://apollo2.humanbrain.in/GW/getBrainViewerDetails/IIT/V1/SS-15:10:1186').text
sectionDetails = json.loads(sectionDetaisRest)

# %%
sectionDetails['Section'][0]
# Out:
# {'order': 0,
#  'key': 'NISSL',
#  'url': 'https://apollo2.humanbrain.in/iipsrv/fcgi-bin/iipsrv.fcgi?FIF=/data/storageIIT/humanbrain/analytics/37/NISL/B_37_FB3-SL_396-ST_NISL-SE_1186_compressed.jp2&WID=1024&RGBGAMA&JTL={z},{tileIndex}',
#  'name': 'NISSL',
#  'type': 'titleLayer',
#  'height': 115928,
#  'width': 83484,
#  'red': {'min': 0, 'max': 255},
#  'green': {'min': 0, 'max': 255},
#  'blue': {'min': 0, 'max': 255},
#  'gama': 1.4,
#  'opacity': 0.9,
#  'rigidrotation': 90,
#  'family': 'brain',
#  'sublayers': [],
#  'trsdata': None}

# %% [markdown]
# ## get annotation types

# %%
headers= {'Authorization': 'Basic YWRtaW46YWRtaW4='}
annotationTypeResp = requests.get('https://apollo2.humanbrain.in/BR/AppAnnotationType/', headers={'Authorization': 'Basic YWRtaW46YWRtaW4='})
annotationType = json.loads(annotationTypeResp.text)

# %%
annotationType
# Out:
# [{'id': 3,
#   'app_annotation_tree_name': 'PixelAnnotation',
#   'app_annotation_tree_json': '{"msg":[{"text":"Cell Type","id":11,"acronym":"CEL","name":"Cell Type","color_hex_triplet":"0000ff","parent_structure_id":1,"children":[{"text":"Type1","id":14,"acronym":"CT1","name":"Type1","color_hex_triplet":"038003","parent_structure_id":1,"children":[]},{"text":"Type2","id":15,"acronym":"CT2","name":"Type2","color_hex_triplet":"87E687","parent_structure_id":1,"children":[]},{"text":"Type3","id":16,"acronym":"CT3","name":"Type3","color_hex_triplet":"1E4A1E","parent_structure_id":1,"children":[]}]}]}',
#   'app_annotation_tree_editable': True,
#   'app_annotation_tree_creator': 'admin'},
#  {'id': 4,
#   'app_annotation_tree_name': 'Atlas',
# ...

# %%
import backendApi  
testVar = backendApi.getListOfSpecies(118152289966904065849)
print(testVar)
# Out:
# {"status":true,"error":{"errorCode":"0","errorMessage":""},"data":[{"data":{"species_name":"chicken (Gallus gallus domesticus)"},"children":[{"data":{"organ_name":"Brain"},"children":[{"data":{"brain_name":"Chicken test brain 1","seriesset_id":77,"series":"   BFI (994), BFIW (992)","count":1986},"children":[]}]}]},{"data":{"species_name":"Goat"},"children":[{"data":{"organ_name":"Brain"},"children":[{"data":{"brain_name":"Goat_Brain4","seriesset_id":14,"series":"  NISL (354)","count":354},"children":[]},{"data":{"brain_name":"Wrong GB16 (CMC) - Delete","seriesset_id":23,"series":"   BFI (395), BFIW (30)","count":425},"children":[]},{"data":{"brain_name":"Goat brain 9","seriesset_id":39,"series":"  HEOS (47)","count":47},"children":[]},{"data":{"brain_name":"goat brain 22","seriesset_id":53,"series":"     BFI (2429), BFIW (2428), HEOS (1), NISL (2)","count":4860},"children":[]},{"data":{"brain_name":"goat brain 21","seriesset_id":54,"series":"     BFI (62), BFIW (62), HEOS (3), NISL (
# ...
